# %%
import skfolio.datasets as skd

print("S&P 500 Dataset ")
df_sp500 = skd.load_sp500_dataset()
print(df_sp500.head(5), "\n")
# Out:
# S&P 500 Dataset
#              AAPL    AMD    BAC    BBY    CVX      GE     HD    JNJ    JPM  \
# Date
# 1990-01-02  0.264  4.125  4.599  0.144  4.991  14.391  1.117  3.438  3.394
# 1990-01-03  0.266  4.000  4.636  0.161  4.910  14.364  1.121  3.452  3.508
# 1990-01-04  0.267  3.938  4.537  0.159  4.847  14.283  1.128  3.459  3.522
# 1990-01-05  0.268  3.812  4.438  0.159  4.775  14.148  1.113  3.423  3.536
# 1990-01-08  0.269  3.812  4.463  0.147  4.820  14.229  1.102  3.481  3.536
#
#                KO    LLY    MRK   MSFT    PEP    PFE     PG    RRC    UNH  \
# Date
# 1990-01-02  2.235  6.658  4.215  0.384  4.738  1.021  3.860  3.322  0.310
# 1990-01-03  2.203  6.658  4.282  0.386  4.692  1.024  3.853  3.322  0.304
# 1990-01-04  2.192  6.621  4.215  0.397  4.646  1.041  3.777  3.322  0.301
# 1990-01-05  2.174  6.549  4.128  0.387  4.581  1.032  3.709  3.322  0.288
# 1990-01-08  2.220  6.549  4.181  0.393  4.664  1.023  3.777  3.322  0.282
#
#               WMT    XOM
# Date
# ...

# %%
print(" S&P 500 Index ")
df_sp500_index = skd.load_sp500_index()
print(df_sp500_index.head(5), "\n")
# Out:
#  S&P 500 Index
#              SP500
# Date
# 1990-01-02  359.69
# 1990-01-03  358.76
# 1990-01-04  355.67
# 1990-01-05  352.20
# 1990-01-08  353.79

# %%
print("Factors Dataset ")
df_factors = skd.load_factors_dataset()
print(df_factors.head(5), "\n")
# Out:
# Factors Dataset
#               MTUM    QUAL    SIZE    USMV    VLUE
# Date
# 2014-01-02  52.704  48.351  48.986  29.338  47.054
# 2014-01-03  52.792  48.256  48.722  29.330  46.999
# 2014-01-06  52.677  48.067  48.722  29.263  46.991
# 2014-01-07  53.112  48.455  48.731  29.430  47.253
# 2014-01-08  53.502  48.437  48.731  29.422  47.253

# %%
print("FTSE 100 Dataset ")
df_ftse100 = skd.load_ftse100_dataset()
print(df_ftse100.head(5), "\n")
# Out:
# FTSE 100 Dataset
#               AAL.L    ABF.L   AHT.L  ANTO.L     AV.L     AZN.L     BA.L  \
# Date
# 2000-01-04  535.354  205.926  97.590  40.313  255.620  1035.377  152.524
# 2000-01-05  540.039  209.185  96.729  40.313  247.940  1014.196  149.817
# 2000-01-06  553.289  229.048  95.581  40.452  245.746  1012.092  151.124
# 2000-01-07  572.829  222.220  95.581  40.452  251.231  1036.115  144.964
# 2000-01-10  578.852  224.548  92.711  40.685  252.877  1064.781  141.977
#
#              BARC.L  BATS.L  BDEV.L  ...    STJ.L    SVT.L   TSCO.L    TW.L  \
# Date                                 ...
# 2000-01-04  178.485  97.129  86.091  ...  117.425  263.170   99.278  46.747
# 2000-01-05  174.210  98.079  85.339  ...  114.510  266.926  100.916  48.610
# 2000-01-06  167.690  95.959  85.038  ...  125.908  287.255  100.916  49.795
# 2000-01-07  163.949  96.836  86.694  ...  133.595  297.419   99.551  50.981
# 2000-01-10  166.194  95.521  83.232  ...  127.498  294.326   96.410  49.287
#
# ...

# %%
print(" NASDAQ Dataset ")
df_nasdaq = skd.load_nasdaq_dataset()
print(df_nasdaq.head(5), "\n")
# Out:
#  NASDAQ Dataset
#                AAL   AAOI    AAON    AAPL    ABCB   ACAD     ACB   ACER  \
# Date
# 2018-01-02  51.648  37.91  35.621  41.310  44.822  30.43  113.76  14.81
# 2018-01-03  51.014  37.89  36.247  41.303  45.007  29.51  135.72  15.81
# 2018-01-04  51.336  38.38  36.103  41.495  45.468  28.78  125.40  16.36
# 2018-01-05  51.316  38.89  36.681  41.967  46.530  28.90  127.32  16.38
# 2018-01-08  50.809  38.37  36.103  41.811  46.530  27.11  134.22  15.69
#
#               ACGL    ACGN  ...    ZEUS     ZG    ZION   ZKIN   ZLAB   ZUMZ  \
# Date                        ...
# 2018-01-02  29.433  300.56  ...  21.482  42.30  46.022  11.47  22.26  20.00
# 2018-01-03  29.460  304.64  ...  22.099  42.73  45.967  11.50  22.35  20.50
# 2018-01-04  29.570  303.28  ...  21.829  42.01  46.158  11.57  22.10  22.95
# 2018-01-05  29.453  308.72  ...  21.482  42.34  46.176  11.42  22.81  22.55
# 2018-01-08  29.457  296.48  ...  22.041  42.62  45.949  12.09  22.98  23.00
#
# ...

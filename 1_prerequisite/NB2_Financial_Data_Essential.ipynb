# %% [markdown]
# # Financial Data - Essential Workflows

# %% [markdown]
# ## Importing and Exporting Stock Price Data from Yahoo Finance

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# %%
ticker = ["AAPL", "BA", "KO", "IBM", "DIS", "MSFT" ]

# %%
stocks = yf.download(ticker, start = "2010-01-01", end = "2019-02-06")
# Out:
# C:\Users\arsh\AppData\Local\Temp\ipykernel_25860\1396029402.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   stocks = yf.download(ticker, start = "2010-01-01", end = "2019-02-06")
# [*********************100%***********************]  6 of 6 completed

# %%
stocks.head()
# Out:
# Price          Close                                                         \
# Ticker          AAPL         BA        DIS        IBM         KO       MSFT
# Date
# 2010-01-04  6.424606  43.777550  27.475880  73.283325  17.692520  23.211439
# 2010-01-05  6.435713  45.211346  27.407339  72.398079  17.478497  23.218941
# 2010-01-06  6.333344  46.582806  27.261690  71.927765  17.472292  23.076450
# 2010-01-07  6.321638  48.468555  27.270256  71.678787  17.428860  22.836464
# 2010-01-08  6.363666  48.001011  27.313093  72.398079  17.106276  22.993952
#
# Price           High                                   ...       Open  \
# Ticker          AAPL         BA        DIS        IBM  ...        DIS
# Date                                                   ...
# 2010-01-04  6.439316  43.941189  28.058468  73.571036  ...  27.844281
# 2010-01-05  6.472038  45.413946  27.552986  72.951370  ...  27.475879
# 2010-01-06  6.461230  46.746448  27.415905  72.752169  ...  27.330230
# 2010-01-07  6.364267  48.554272  27.295959  72.066088  ...  27.218852
# 2010-01-08  6.364266  48.141274  27.364499  72.436807  ...  27.124609
#
# Price                                           Volume                      \
# Ticker            IBM         KO       MSFT       AAPL        BA       DIS
# Date
# 2010-01-04  72.580646  17.729741  22.963951  493729600   6186700  13700400
# 2010-01-05  72.857308  17.633585  23.136445  601904800   8867800  10307700
# 2010-01-06  72.304001  17.478494  23.158946  552160000   8836500  10709500
# 2010-01-07  71.855838  17.472286  22.971457  477131200  14379100   8202100
# 2010-01-08  71.413221  17.202430  22.708965  447610800   7146600   7657500
#
# Price
# Ticker          IBM        KO      MSFT
# Date
# 2010-01-04  6438444  13870400  38409100
# 2010-01-05  7156104  23172400  49749600
# 2010-01-06  5863144  19264600  58182400
# 2010-01-07  6109268  13234600  50559700
# 2010-01-08  4390271  28712400  51197400
#
# [5 rows x 30 columns]

# %%
stocks.tail()
# Out:
# Price           Close                                                \
# Ticker           AAPL          BA         DIS        IBM         KO
# Date
# 2019-01-30  39.319302  376.746307  107.016296  95.225594  39.160088
# 2019-01-31  39.602440  374.705719  108.366989  95.253914  39.381008
# 2019-02-01  39.621479  376.464508  108.153206  95.027184  39.847385
# 2019-02-04  40.746922  385.763641  108.639076  95.799553  40.297417
# 2019-02-05  41.444092  398.570587  109.474770  96.054680  40.305599
#
# Price                        High                                     ...  \
# Ticker            MSFT       AAPL          BA         DIS        IBM  ...
# Date                                                                  ...
# 2019-01-30   99.884315  39.533445  380.876019  107.453578  95.686202  ...
# 2019-01-31   98.053413  40.211561  377.980332  108.386428  95.466501  ...
# 2019-02-01   96.504158  40.206805  381.682515  108.882001  95.806672  ...
# 2019-02-04   99.283394  40.844477  385.831667  108.813987  95.806644  ...
# 2019-02-05  100.673035  41.658238  399.124461  109.552502  96.246003  ...
#
# Price             Open                                      Volume            \
# Ticker             DIS        IBM         KO       MSFT       AAPL        BA
# Date
# 2019-01-30  107.181496  94.956309  38.660972  98.231788  244439200  12705300
# 2019-01-31  106.987139  95.275177  39.151904  97.461884  162958400   6878500
# 2019-02-01  108.804261  95.643692  39.667376  97.443097  130672400   5625700
# 2019-02-04  108.260103  94.970458  39.847395  96.588644  125982000   4256600
# 2019-02-05  108.852857  95.863345  40.362878  99.583862  144406400   7230400
#
# Price
# Ticker           DIS      IBM        KO      MSFT
# Date
# 2019-01-30   7853800  4707941  12952500  49471900
# 2019-01-31   8351600  5108664  32181500  55636400
# 2019-02-01   6557700  3981076  19130100  35535700
# 2019-02-04   7037000  4149064  15105700  31315100
# 2019-02-05  13619800  5647249  12651900  27325400
#
# [5 rows x 30 columns]

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2288 entries, 2010-01-04 to 2019-02-05
# Data columns (total 30 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, AAPL)   2288 non-null   float64
#  1   (Close, BA)     2288 non-null   float64
#  2   (Close, DIS)    2288 non-null   float64
#  3   (Close, IBM)    2288 non-null   float64
#  4   (Close, KO)     2288 non-null   float64
#  5   (Close, MSFT)   2288 non-null   float64
#  6   (High, AAPL)    2288 non-null   float64
#  7   (High, BA)      2288 non-null   float64
#  8   (High, DIS)     2288 non-null   float64
#  9   (High, IBM)     2288 non-null   float64
#  10  (High, KO)      2288 non-null   float64
#  11  (High, MSFT)    2288 non-null   float64
#  12  (Low, AAPL)     2288 non-null   float64
#  13  (Low, BA)       2288 non-null   float64
#  14  (Low, DIS)      2288 non-null   float64
#  15  (Low, IBM)      2288 non-null   float64
#  16  (Low, KO)       2288 non-null   float64
#  17  (Low, MSFT)     2288 non-null   float64
#  18  (Open, AAPL)    2288 non-null   float64
#  19  (Open, BA)      2288 non-null   float64
#  20  (Open, DIS)     2288 non-null   float64
#  21  (Open, IBM)     2288 non-null   float64
#  22  (Open, KO)      2288 non-null   float64
#  23  (Open, MSFT)    2288 non-null   float64
#  24  (Volume, AAPL)  2288 non-null   int64
#  25  (Volume, BA)    2288 non-null   int64
#  26  (Volume, DIS)   2288 non-null   int64
#  27  (Volume, IBM)   2288 non-null   int64
#  28  (Volume, KO)    2288 non-null   int64
#  29  (Volume, MSFT)  2288 non-null   int64
# dtypes: float64(24), int64(6)
# memory usage: 554.1 KB

# %%
stocks.to_csv("stocks.csv")

# %%
stocks = pd.read_csv("stocks.csv", header = [0, 1], index_col = [0], parse_dates = [0])

# %%
stocks.head()
# Out:
# Price          Close                                                         \
# Ticker          AAPL         BA        DIS        IBM         KO       MSFT
# Date
# 2010-01-04  6.424606  43.777550  27.475880  73.283325  17.692520  23.211439
# 2010-01-05  6.435713  45.211346  27.407339  72.398079  17.478497  23.218941
# 2010-01-06  6.333344  46.582806  27.261690  71.927765  17.472292  23.076450
# 2010-01-07  6.321638  48.468555  27.270256  71.678787  17.428860  22.836464
# 2010-01-08  6.363666  48.001011  27.313093  72.398079  17.106276  22.993952
#
# Price           High                                   ...       Open  \
# Ticker          AAPL         BA        DIS        IBM  ...        DIS
# Date                                                   ...
# 2010-01-04  6.439316  43.941189  28.058468  73.571036  ...  27.844281
# 2010-01-05  6.472038  45.413946  27.552986  72.951370  ...  27.475879
# 2010-01-06  6.461230  46.746448  27.415905  72.752169  ...  27.330230
# 2010-01-07  6.364267  48.554272  27.295959  72.066088  ...  27.218852
# 2010-01-08  6.364266  48.141274  27.364499  72.436807  ...  27.124609
#
# Price                                           Volume                      \
# Ticker            IBM         KO       MSFT       AAPL        BA       DIS
# Date
# 2010-01-04  72.580646  17.729741  22.963951  493729600   6186700  13700400
# 2010-01-05  72.857308  17.633585  23.136445  601904800   8867800  10307700
# 2010-01-06  72.304001  17.478494  23.158946  552160000   8836500  10709500
# 2010-01-07  71.855838  17.472286  22.971457  477131200  14379100   8202100
# 2010-01-08  71.413221  17.202430  22.708965  447610800   7146600   7657500
#
# Price
# Ticker          IBM        KO      MSFT
# Date
# 2010-01-04  6438444  13870400  38409100
# 2010-01-05  7156104  23172400  49749600
# 2010-01-06  5863144  19264600  58182400
# 2010-01-07  6109268  13234600  50559700
# 2010-01-08  4390271  28712400  51197400
#
# [5 rows x 30 columns]

# %%
stocks.columns = stocks.columns.to_flat_index()

# %%
stocks.columns
# Out:
# Index([ ('Close', 'AAPL'),    ('Close', 'BA'),   ('Close', 'DIS'),
#          ('Close', 'IBM'),    ('Close', 'KO'),  ('Close', 'MSFT'),
#          ('High', 'AAPL'),     ('High', 'BA'),    ('High', 'DIS'),
#           ('High', 'IBM'),     ('High', 'KO'),   ('High', 'MSFT'),
#           ('Low', 'AAPL'),      ('Low', 'BA'),     ('Low', 'DIS'),
#            ('Low', 'IBM'),      ('Low', 'KO'),    ('Low', 'MSFT'),
#          ('Open', 'AAPL'),     ('Open', 'BA'),    ('Open', 'DIS'),
#           ('Open', 'IBM'),     ('Open', 'KO'),   ('Open', 'MSFT'),
#        ('Volume', 'AAPL'),   ('Volume', 'BA'),  ('Volume', 'DIS'),
#         ('Volume', 'IBM'),   ('Volume', 'KO'), ('Volume', 'MSFT')],
#       dtype='object')

# %%
stocks.columns = pd.MultiIndex.from_tuples(stocks.columns)

# %%
stocks.head()
# Out:
#                Close                                                         \
#                 AAPL         BA        DIS        IBM         KO       MSFT
# Date
# 2010-01-04  6.424606  43.777550  27.475880  73.283325  17.692520  23.211439
# 2010-01-05  6.435713  45.211346  27.407339  72.398079  17.478497  23.218941
# 2010-01-06  6.333344  46.582806  27.261690  71.927765  17.472292  23.076450
# 2010-01-07  6.321638  48.468555  27.270256  71.678787  17.428860  22.836464
# 2010-01-08  6.363666  48.001011  27.313093  72.398079  17.106276  22.993952
#
#                 High                                   ...       Open  \
#                 AAPL         BA        DIS        IBM  ...        DIS
# Date                                                   ...
# 2010-01-04  6.439316  43.941189  28.058468  73.571036  ...  27.844281
# 2010-01-05  6.472038  45.413946  27.552986  72.951370  ...  27.475879
# 2010-01-06  6.461230  46.746448  27.415905  72.752169  ...  27.330230
# 2010-01-07  6.364267  48.554272  27.295959  72.066088  ...  27.218852
# 2010-01-08  6.364266  48.141274  27.364499  72.436807  ...  27.124609
#
#                                                 Volume                      \
#                   IBM         KO       MSFT       AAPL        BA       DIS
# Date
# 2010-01-04  72.580646  17.729741  22.963951  493729600   6186700  13700400
# 2010-01-05  72.857308  17.633585  23.136445  601904800   8867800  10307700
# 2010-01-06  72.304001  17.478494  23.158946  552160000   8836500  10709500
# 2010-01-07  71.855838  17.472286  22.971457  477131200  14379100   8202100
# 2010-01-08  71.413221  17.202430  22.708965  447610800   7146600   7657500
#
#
#                 IBM        KO      MSFT
# Date
# 2010-01-04  6438444  13870400  38409100
# 2010-01-05  7156104  23172400  49749600
# 2010-01-06  5863144  19264600  58182400
# 2010-01-07  6109268  13234600  50559700
# 2010-01-08  4390271  28712400  51197400
#
# [5 rows x 30 columns]

# %%
stocks.swaplevel(axis = 1).sort_index(axis = 1)
# Out:
#                  AAPL                                                      BA  \
#                 Close       High        Low       Open     Volume       Close
# Date
# 2010-01-04   6.424606   6.439316   6.375673   6.407194  493729600   43.777550
# 2010-01-05   6.435713   6.472038   6.401790   6.442318  601904800   45.211346
# 2010-01-06   6.333344   6.461230   6.326739   6.435713  552160000   46.582806
# 2010-01-07   6.321638   6.364267   6.275707   6.356762  477131200   48.468555
# 2010-01-08   6.363666   6.364266   6.276008   6.313232  447610800   48.001011
# ...               ...        ...        ...        ...        ...         ...
# 2019-01-30  39.319302  39.533445  38.124850  38.843425  244439200  376.746307
# 2019-01-31  39.602440  40.211561  39.155115  39.523920  162958400  374.705719
# 2019-02-01  39.621479  40.206805  39.481093  39.726172  130672400  376.464508
# 2019-02-04  40.746922  40.844477  39.802306  39.833240  125982000  385.763641
# 2019-02-05  41.444092  41.658238  41.008668  41.130015  144406400  398.570587
#
#                                                           ...         KO  \
#                   High         Low        Open    Volume  ...      Close
# Date                                                      ...
# 2010-01-04   43.941189   42.702201   43.419101   6186700  ...  17.692520
# 2010-01-05   45.413946   43.637286   43.832095   8867800  ...  17.478497
# 2010-01-06   46.746448   45.102257   45.374988   8836500  ...  17.472292
# 2010-01-07   48.554272   45.990581   46.372405  14379100  ...  17.428860
# 2010-01-08   48.141274   47.424377   47.954259   7146600  ...  17.106276
# ...                ...         ...         ...       ...  ...        ...
# 2019-01-30  380.876019  369.730655  376.435357  12705300  ...  39.160088
# 2019-01-31  377.980332  371.265904  376.202140   6878500  ...  39.381008
# 2019-02-01  381.682515  373.840944  375.181861   5625700  ...  39.847385
# 2019-02-04  385.831667  377.134969  377.960917   4256600  ...  40.297417
# 2019-02-05  399.124461  388.241445  389.407493   7230400  ...  40.305599
#
#                                                              MSFT              \
#                  High        Low       Open    Volume       Close        High
# Date
# 2010-01-04  17.748352  17.649095  17.729741  13870400   23.211439   23.323934
# 2010-01-05  17.677011  17.413360  17.633585  23172400   23.218941   23.323937
# 2010-01-06  17.506410  17.363729  17.478494  19264600   23.076450   23.308939
# 2010-01-07  17.484692  17.292382  17.472286  13234600   22.836464   23.023955
# 2010-01-08  17.258262  16.982204  17.202430  28712400   22.993952   23.158944
# ...               ...        ...        ...       ...         ...         ...
# 2019-01-30  39.184633  38.611877  38.660972  12952500   99.884315   99.884315
# 2019-01-31  39.912850  38.840982  39.151904  32181500   98.053413   98.795176
# 2019-02-01  39.912841  39.601920  39.667376  19130100   96.504158   97.743557
# 2019-02-04  40.461062  39.716480  39.847395  15105700   99.283394   99.339735
# 2019-02-05  40.477428  40.174684  40.362878  12651900  100.673035  100.719977
#
#
#                   Low       Open    Volume
# Date
# 2010-01-04  22.941451  22.963951  38409100
# 2010-01-05  22.978952  23.136445  49749600
# 2010-01-06  22.888959  23.158946  58182400
# 2010-01-07  22.641473  22.971457  50559700
# 2010-01-08  22.678966  22.708965  51197400
# ...               ...        ...       ...
# 2019-01-30  97.959495  98.231788  49471900
# 2019-01-31  96.879739  97.461884  55636400
# 2019-02-01  96.100414  97.443097  35535700
# 2019-02-04  96.494744  96.588644  31315100
# 2019-02-05  99.489970  99.583862  27325400
#
# [2288 rows x 30 columns]

# %% [markdown]
# ## Initial Inspection and Visualization

# %%
import pandas as pd

# %%
stocks = pd.read_csv("stocks.csv", header = [0,1], index_col= [0], parse_dates= [0])

# %%
stocks.head()
# Out:
# Price          Close                                                         \
# Ticker          AAPL         BA        DIS        IBM         KO       MSFT
# Date
# 2010-01-04  6.424606  43.777550  27.475880  73.283325  17.692520  23.211439
# 2010-01-05  6.435713  45.211346  27.407339  72.398079  17.478497  23.218941
# 2010-01-06  6.333344  46.582806  27.261690  71.927765  17.472292  23.076450
# 2010-01-07  6.321638  48.468555  27.270256  71.678787  17.428860  22.836464
# 2010-01-08  6.363666  48.001011  27.313093  72.398079  17.106276  22.993952
#
# Price           High                                   ...       Open  \
# Ticker          AAPL         BA        DIS        IBM  ...        DIS
# Date                                                   ...
# 2010-01-04  6.439316  43.941189  28.058468  73.571036  ...  27.844281
# 2010-01-05  6.472038  45.413946  27.552986  72.951370  ...  27.475879
# 2010-01-06  6.461230  46.746448  27.415905  72.752169  ...  27.330230
# 2010-01-07  6.364267  48.554272  27.295959  72.066088  ...  27.218852
# 2010-01-08  6.364266  48.141274  27.364499  72.436807  ...  27.124609
#
# Price                                           Volume                      \
# Ticker            IBM         KO       MSFT       AAPL        BA       DIS
# Date
# 2010-01-04  72.580646  17.729741  22.963951  493729600   6186700  13700400
# 2010-01-05  72.857308  17.633585  23.136445  601904800   8867800  10307700
# 2010-01-06  72.304001  17.478494  23.158946  552160000   8836500  10709500
# 2010-01-07  71.855838  17.472286  22.971457  477131200  14379100   8202100
# 2010-01-08  71.413221  17.202430  22.708965  447610800   7146600   7657500
#
# Price
# Ticker          IBM        KO      MSFT
# Date
# 2010-01-04  6438444  13870400  38409100
# 2010-01-05  7156104  23172400  49749600
# 2010-01-06  5863144  19264600  58182400
# 2010-01-07  6109268  13234600  50559700
# 2010-01-08  4390271  28712400  51197400
#
# [5 rows x 30 columns]

# %%
stocks.tail()
# Out:
# Price           Close                                                \
# Ticker           AAPL          BA         DIS        IBM         KO
# Date
# 2019-01-30  39.319302  376.746307  107.016296  95.225594  39.160088
# 2019-01-31  39.602440  374.705719  108.366989  95.253914  39.381008
# 2019-02-01  39.621479  376.464508  108.153206  95.027184  39.847385
# 2019-02-04  40.746922  385.763641  108.639076  95.799553  40.297417
# 2019-02-05  41.444092  398.570587  109.474770  96.054680  40.305599
#
# Price                        High                                     ...  \
# Ticker            MSFT       AAPL          BA         DIS        IBM  ...
# Date                                                                  ...
# 2019-01-30   99.884315  39.533445  380.876019  107.453578  95.686202  ...
# 2019-01-31   98.053413  40.211561  377.980332  108.386428  95.466501  ...
# 2019-02-01   96.504158  40.206805  381.682515  108.882001  95.806672  ...
# 2019-02-04   99.283394  40.844477  385.831667  108.813987  95.806644  ...
# 2019-02-05  100.673035  41.658238  399.124461  109.552502  96.246003  ...
#
# Price             Open                                      Volume            \
# Ticker             DIS        IBM         KO       MSFT       AAPL        BA
# Date
# 2019-01-30  107.181496  94.956309  38.660972  98.231788  244439200  12705300
# 2019-01-31  106.987139  95.275177  39.151904  97.461884  162958400   6878500
# 2019-02-01  108.804261  95.643692  39.667376  97.443097  130672400   5625700
# 2019-02-04  108.260103  94.970458  39.847395  96.588644  125982000   4256600
# 2019-02-05  108.852857  95.863345  40.362878  99.583862  144406400   7230400
#
# Price
# Ticker           DIS      IBM        KO      MSFT
# Date
# 2019-01-30   7853800  4707941  12952500  49471900
# 2019-01-31   8351600  5108664  32181500  55636400
# 2019-02-01   6557700  3981076  19130100  35535700
# 2019-02-04   7037000  4149064  15105700  31315100
# 2019-02-05  13619800  5647249  12651900  27325400
#
# [5 rows x 30 columns]

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2288 entries, 2010-01-04 to 2019-02-05
# Data columns (total 30 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, AAPL)   2288 non-null   float64
#  1   (Close, BA)     2288 non-null   float64
#  2   (Close, DIS)    2288 non-null   float64
#  3   (Close, IBM)    2288 non-null   float64
#  4   (Close, KO)     2288 non-null   float64
#  5   (Close, MSFT)   2288 non-null   float64
#  6   (High, AAPL)    2288 non-null   float64
#  7   (High, BA)      2288 non-null   float64
#  8   (High, DIS)     2288 non-null   float64
#  9   (High, IBM)     2288 non-null   float64
#  10  (High, KO)      2288 non-null   float64
#  11  (High, MSFT)    2288 non-null   float64
#  12  (Low, AAPL)     2288 non-null   float64
#  13  (Low, BA)       2288 non-null   float64
#  14  (Low, DIS)      2288 non-null   float64
#  15  (Low, IBM)      2288 non-null   float64
#  16  (Low, KO)       2288 non-null   float64
#  17  (Low, MSFT)     2288 non-null   float64
#  18  (Open, AAPL)    2288 non-null   float64
#  19  (Open, BA)      2288 non-null   float64
#  20  (Open, DIS)     2288 non-null   float64
#  21  (Open, IBM)     2288 non-null   float64
#  22  (Open, KO)      2288 non-null   float64
#  23  (Open, MSFT)    2288 non-null   float64
#  24  (Volume, AAPL)  2288 non-null   int64
#  25  (Volume, BA)    2288 non-null   int64
#  26  (Volume, DIS)   2288 non-null   int64
#  27  (Volume, IBM)   2288 non-null   int64
#  28  (Volume, KO)    2288 non-null   int64
#  29  (Volume, MSFT)  2288 non-null   int64
# dtypes: float64(24), int64(6)
# memory usage: 554.1 KB

# %%
stocks.describe()
# Out:
# Price         Close                                                      \
# Ticker         AAPL           BA          DIS          IBM           KO
# count   2288.000000  2288.000000  2288.000000  2288.000000  2288.000000
# mean      22.519866   130.186519    70.469946   100.506252    28.308523
# std       11.472542    88.687438    29.321872    13.422119     5.971659
# min        5.765363    43.777550    25.117426    67.717216    15.660818
# 25%       13.222167    60.522989    38.119472    93.887495    24.250586
# 50%       20.992056   111.242439    77.731709   102.183067    28.821646
# 75%       28.304497   135.417160    97.901163   110.972870    32.845632
# max       55.026337   398.570587   114.649040   126.355255    41.238369
#
# Price                       High                                         ...  \
# Ticker         MSFT         AAPL           BA          DIS          IBM  ...
# count   2288.000000  2288.000000  2288.000000  2288.000000  2288.000000  ...
# mean      42.424156    22.719522   131.367468    70.992633   101.190265  ...
# std       24.217267    11.567986    89.687922    29.515888    13.459336  ...
# min       17.415638     5.883941    43.941189    25.256903    68.453082  ...
# 25%       22.748362    13.357606    60.894143    38.352853    94.441073  ...
# 50%       35.471752    21.190545   112.061952    78.460417   102.955992  ...
# 75%       52.717385    28.542873   136.390855    98.514514   111.739337  ...
# max      108.083801    55.358291   399.124461   115.902554   126.413808  ...
#
# Price          Open                                               Volume  \
# Ticker          DIS          IBM           KO         MSFT          AAPL
# count   2288.000000  2288.000000  2288.000000  2288.000000  2.288000e+03
# mean      70.466714   100.474442    28.299460    42.414727  3.187215e+08
# std       29.350516    13.438036     5.967149    24.230141  2.380917e+08
# min       24.883571    67.854829    15.751501    17.476186  4.590360e+07
# 25%       38.040210    93.732497    24.210816    22.728049  1.371571e+08
# 50%       77.926327   102.147412    28.820330    35.414183  2.497872e+08
# 75%       97.910065   111.002559    32.870390    52.726838  4.298973e+08
# max      114.793677   126.109337    41.255802   107.906165  1.880998e+09
#
# Price
# Ticker            BA           DIS           IBM            KO          MSFT
# count   2.288000e+03  2.288000e+03  2.288000e+03  2.288000e+03  2.288000e+03
# mean    4.601274e+06  8.775748e+06  5.025515e+06  1.503227e+07  4.155095e+07
# std     2.440871e+06  4.907867e+06  2.643450e+06  6.574772e+06  2.339253e+07
# min     7.889000e+05  2.165700e+06  1.247878e+06  2.996300e+06  7.425600e+06
# 25%     3.110000e+06  6.053675e+06  3.462156e+06  1.082630e+07  2.590040e+07
# 50%     4.091200e+06  7.602750e+06  4.357636e+06  1.355170e+07  3.600365e+07
# 75%     5.332025e+06  9.948850e+06  5.648164e+06  1.755170e+07  5.160548e+07
# max     4.439180e+07  8.704850e+07  3.189275e+07  9.896750e+07  3.193179e+08
#
# [8 rows x 30 columns]

# %%
close = stocks.loc[:, "Close"].copy()

# %%
close.head()
# Out:
# Ticker          AAPL         BA        DIS        IBM         KO       MSFT
# Date
# 2010-01-04  6.424606  43.777550  27.475880  73.283325  17.692520  23.211439
# 2010-01-05  6.435713  45.211346  27.407339  72.398079  17.478497  23.218941
# 2010-01-06  6.333344  46.582806  27.261690  71.927765  17.472292  23.076450
# 2010-01-07  6.321638  48.468555  27.270256  71.678787  17.428860  22.836464
# 2010-01-08  6.363666  48.001011  27.313093  72.398079  17.106276  22.993952

# %%
import matplotlib.pyplot as plt
plt.style.use("seaborn-v0_8")

# %%
close.plot(figsize = (15, 8 ), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %% [markdown]
# ## Normalizing Time Series to a Base Value (100)

# %%
close.head()
# Out:
# Ticker          AAPL         BA        DIS        IBM         KO       MSFT
# Date
# 2010-01-04  6.424606  43.777550  27.475880  73.283325  17.692520  23.211439
# 2010-01-05  6.435713  45.211346  27.407339  72.398079  17.478497  23.218941
# 2010-01-06  6.333344  46.582806  27.261690  71.927765  17.472292  23.076450
# 2010-01-07  6.321638  48.468555  27.270256  71.678787  17.428860  22.836464
# 2010-01-08  6.363666  48.001011  27.313093  72.398079  17.106276  22.993952

# %%
close.iloc[0,0]
# Out:
# 6.424605846405029

# %%
close.AAPL.div(close.iloc[0,0]).mul(100)
# Out:
# Date
# 2010-01-04    100.000000
# 2010-01-05    100.172889
# 2010-01-06     98.579495
# 2010-01-07     98.397284
# 2010-01-08     99.051455
#                  ...
# 2019-01-30    612.011111
# 2019-01-31    616.418203
# 2019-02-01    616.714550
# 2019-02-04    634.232240
# 2019-02-05    645.083804
# Name: AAPL, Length: 2288, dtype: float64

# %%
close.iloc[0]
# Out:
# Ticker
# AAPL     6.424606
# BA      43.777550
# DIS     27.475880
# IBM     73.283325
# KO      17.692520
# MSFT    23.211439
# Name: 2010-01-04 00:00:00, dtype: float64

# %%
norm = close.div(close.iloc[0]).mul(100)
norm
# Out:
# Ticker            AAPL          BA         DIS         IBM          KO  \
# Date
# 2010-01-04  100.000000  100.000000  100.000000  100.000000  100.000000
# 2010-01-05  100.172889  103.275185   99.750543   98.792022   98.790316
# 2010-01-06   98.579495  106.407978   99.220445   98.150247   98.755247
# 2010-01-07   98.397284  110.715551   99.251621   97.810501   98.509763
# 2010-01-08   99.051455  109.647550   99.407529   98.792022   96.686483
# ...                ...         ...         ...         ...         ...
# 2019-01-30  612.011111  860.592495  389.491793  129.941693  221.336968
# 2019-01-31  616.418203  855.931228  394.407715  129.980338  222.585634
# 2019-02-01  616.714550  859.948787  393.629639  129.670949  225.221648
# 2019-02-04  634.232240  881.190573  395.397991  130.724899  227.765272
# 2019-02-05  645.083804  910.445170  398.439544  131.073037  227.811521
#
# Ticker            MSFT
# Date
# 2010-01-04  100.000000
# 2010-01-05  100.032319
# 2010-01-06   99.418439
# 2010-01-07   98.384524
# 2010-01-08   99.063017
# ...                ...
# 2019-01-30  430.323665
# 2019-01-31  422.435735
# 2019-02-01  415.761201
# 2019-02-04  427.734762
# 2019-02-05  433.721641
#
# [2288 rows x 6 columns]

# %%
norm.plot(figsize = (15, 8 ), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %% [markdown]
# ## The shift() method

# %%
close.head()
# Out:
# Ticker          AAPL         BA        DIS        IBM         KO       MSFT
# Date
# 2010-01-04  6.424606  43.777550  27.475880  73.283325  17.692520  23.211439
# 2010-01-05  6.435713  45.211346  27.407339  72.398079  17.478497  23.218941
# 2010-01-06  6.333344  46.582806  27.261690  71.927765  17.472292  23.076450
# 2010-01-07  6.321638  48.468555  27.270256  71.678787  17.428860  22.836464
# 2010-01-08  6.363666  48.001011  27.313093  72.398079  17.106276  22.993952

# %%
aapl = close.AAPL.copy().to_frame()

# %%
aapl.head()
# Out:
#                 AAPL
# Date
# 2010-01-04  6.424606
# 2010-01-05  6.435713
# 2010-01-06  6.333344
# 2010-01-07  6.321638
# 2010-01-08  6.363666

# %%
aapl.shift(periods = 1)
# Out:
#                  AAPL
# Date
# 2010-01-04        NaN
# 2010-01-05   6.424606
# 2010-01-06   6.435713
# 2010-01-07   6.333344
# 2010-01-08   6.321638
# ...               ...
# 2019-01-30  36.804291
# 2019-01-31  39.319302
# 2019-02-01  39.602440
# 2019-02-04  39.621479
# 2019-02-05  40.746922
#
# [2288 rows x 1 columns]

# %%
aapl["lag1"] = aapl.shift(periods = 1)

# %%
aapl.head()
# Out:
#                 AAPL      lag1
# Date
# 2010-01-04  6.424606       NaN
# 2010-01-05  6.435713  6.424606
# 2010-01-06  6.333344  6.435713
# 2010-01-07  6.321638  6.333344
# 2010-01-08  6.363666  6.321638

# %%
aapl.AAPL.sub(aapl.lag1)
# Out:
# Date
# 2010-01-04         NaN
# 2010-01-05    0.011107
# 2010-01-06   -0.102369
# 2010-01-07   -0.011706
# 2010-01-08    0.042028
#                 ...
# 2019-01-30    2.515011
# 2019-01-31    0.283138
# 2019-02-01    0.019039
# 2019-02-04    1.125443
# 2019-02-05    0.697170
# Length: 2288, dtype: float64

# %%
aapl["Diff"] = aapl.AAPL.sub(aapl.lag1)

# %%
aapl.head()
# Out:
#                 AAPL      lag1      Diff
# Date
# 2010-01-04  6.424606       NaN       NaN
# 2010-01-05  6.435713  6.424606  0.011107
# 2010-01-06  6.333344  6.435713 -0.102369
# 2010-01-07  6.321638  6.333344 -0.011706
# 2010-01-08  6.363666  6.321638  0.042028

# %%
aapl.AAPL.div(aapl.lag1).sub(1).mul(100)
# Out:
# Date
# 2010-01-04         NaN
# 2010-01-05    0.172889
# 2010-01-06   -1.590644
# 2010-01-07   -0.184837
# 2010-01-08    0.664827
#                 ...
# 2019-01-30    6.833472
# 2019-01-31    0.720100
# 2019-02-01    0.048076
# 2019-02-04    2.840486
# 2019-02-05    1.710977
# Length: 2288, dtype: float64

# %%
aapl["pct_change"] = aapl.AAPL.div(aapl.lag1).sub(1).mul(100)

# %%
aapl.head()
# Out:
#                 AAPL      lag1      Diff  pct_change
# Date
# 2010-01-04  6.424606       NaN       NaN         NaN
# 2010-01-05  6.435713  6.424606  0.011107    0.172889
# 2010-01-06  6.333344  6.435713 -0.102369   -1.590644
# 2010-01-07  6.321638  6.333344 -0.011706   -0.184837
# 2010-01-08  6.363666  6.321638  0.042028    0.664827

# %% [markdown]
# ## The methods diff() and pct_change()

# %%
aapl.head()
# Out:
#                 AAPL      lag1      Diff  pct_change
# Date
# 2010-01-04  6.424606       NaN       NaN         NaN
# 2010-01-05  6.435713  6.424606  0.011107    0.172889
# 2010-01-06  6.333344  6.435713 -0.102369   -1.590644
# 2010-01-07  6.321638  6.333344 -0.011706   -0.184837
# 2010-01-08  6.363666  6.321638  0.042028    0.664827

# %%
aapl.AAPL.diff(periods = 2)
# Out:
# Date
# 2010-01-04         NaN
# 2010-01-05         NaN
# 2010-01-06   -0.091262
# 2010-01-07   -0.114076
# 2010-01-08    0.030322
#                 ...
# 2019-01-30    2.129551
# 2019-01-31    2.798149
# 2019-02-01    0.302177
# 2019-02-04    1.144482
# 2019-02-05    1.822613
# Name: AAPL, Length: 2288, dtype: float64

# %%
aapl["Diff2"] = aapl.AAPL.diff(periods = 1)

# %%
aapl.head(10)
# Out:
#                 AAPL      lag1      Diff  pct_change     Diff2
# Date
# 2010-01-04  6.424606       NaN       NaN         NaN       NaN
# 2010-01-05  6.435713  6.424606  0.011107    0.172889  0.011107
# 2010-01-06  6.333344  6.435713 -0.102369   -1.590644 -0.102369
# 2010-01-07  6.321638  6.333344 -0.011706   -0.184837 -0.011706
# 2010-01-08  6.363666  6.321638  0.042028    0.664827  0.042028
# 2010-01-11  6.307528  6.363666 -0.056138   -0.882165 -0.056138
# 2010-01-12  6.235778  6.307528 -0.071749   -1.137517 -0.071749
# 2010-01-13  6.323739  6.235778  0.087960    1.410574  0.087960
# 2010-01-14  6.287112  6.323739 -0.036627   -0.579196 -0.036627
# 2010-01-15  6.182042  6.287112 -0.105070   -1.671198 -0.105070

# %%
aapl.Diff.equals(aapl.Diff2)
# Out:
# True

# %%
aapl["pct_change2"] = aapl.AAPL.pct_change(periods = 1).mul(100)

# %%
aapl.head()
# Out:
#                 AAPL      lag1      Diff  pct_change     Diff2  pct_change2
# Date
# 2010-01-04  6.424606       NaN       NaN         NaN       NaN          NaN
# 2010-01-05  6.435713  6.424606  0.011107    0.172889  0.011107     0.172889
# 2010-01-06  6.333344  6.435713 -0.102369   -1.590644 -0.102369    -1.590644
# 2010-01-07  6.321638  6.333344 -0.011706   -0.184837 -0.011706    -0.184837
# 2010-01-08  6.363666  6.321638  0.042028    0.664827  0.042028     0.664827

# %%
aapl.AAPL.resample("BME").last().pct_change(periods =1).mul(100) # New: BME
# Out:
# Date
# 2010-01-29          NaN
# 2010-02-26     6.539626
# 2010-03-31    14.847034
# 2010-04-30    11.102145
# 2010-05-31    -1.612502
#                 ...
# 2018-10-31    -3.047757
# 2018-11-30   -18.119722
# 2018-12-31   -11.669864
# 2019-01-31     5.515400
# 2019-02-28     4.650350
# Freq: BME, Name: AAPL, Length: 110, dtype: float64

# %% [markdown]
# ## Measuring Stock Perfromance with MEAN Return and STD of Returns

# %%
import numpy as np

# %%
aapl = close.AAPL.copy().to_frame()

# %%
aapl.head()
# Out:
#                 AAPL
# Date
# 2010-01-04  6.424606
# 2010-01-05  6.435713
# 2010-01-06  6.333344
# 2010-01-07  6.321638
# 2010-01-08  6.363666

# %%
aapl.pct_change().dropna()
# Out:
#                 AAPL
# Date
# 2010-01-05  0.001729
# 2010-01-06 -0.015906
# 2010-01-07 -0.001848
# 2010-01-08  0.006648
# 2010-01-11 -0.008822
# ...              ...
# 2019-01-30  0.068335
# 2019-01-31  0.007201
# 2019-02-01  0.000481
# 2019-02-04  0.028405
# 2019-02-05  0.017110
#
# [2287 rows x 1 columns]

# %%
ret = aapl.pct_change().dropna()
ret.head()
# Out:
#                 AAPL
# Date
# 2010-01-05  0.001729
# 2010-01-06 -0.015906
# 2010-01-07 -0.001848
# 2010-01-08  0.006648
# 2010-01-11 -0.008822

# %%
ret.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2287 entries, 2010-01-05 to 2019-02-05
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    2287 non-null   float64
# dtypes: float64(1)
# memory usage: 35.7 KB

# %%
ret.plot(kind = "hist", figsize = (12 ,8), bins = 100)
plt.show()

# %%
daily_mean_Return = ret.mean()
daily_mean_Return
# Out:
# AAPL    0.00095
# dtype: float64

# %%
var_daily_Returns = ret.var()
var_daily_Returns
# Out:
# AAPL    0.000268
# dtype: float64

# %%
std_daily_Returns = np.sqrt(var_daily_Returns)
std_daily_Returns
# Out:
# AAPL    0.016383
# dtype: float64

# %%
ret.std()
# Out:
# AAPL    0.016383
# dtype: float64

# %%
ann_mean_Return = ret.mean() * 252
ann_mean_Return
# Out:
# AAPL    0.239358
# dtype: float64

# %%
ann_var_Returns = ret.var() * 252
ann_var_Returns
# Out:
# AAPL    0.067634
# dtype: float64

# %%
ann_std_Returns = np.sqrt(ann_var_Returns)
ann_std_Returns
# Out:
# AAPL    0.260066
# dtype: float64

# %%
ret.std() * np.sqrt(252)
# Out:
# AAPL    0.260066
# dtype: float64

# %% [markdown]
# ## Financial Time Series - Return and Risk

# %%
import numpy as np

# %%
norm.plot(figsize = (15, 8 ), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %%
close.head()
# Out:
# Ticker          AAPL         BA        DIS        IBM         KO       MSFT
# Date
# 2010-01-04  6.424606  43.777550  27.475880  73.283325  17.692520  23.211439
# 2010-01-05  6.435713  45.211346  27.407339  72.398079  17.478497  23.218941
# 2010-01-06  6.333344  46.582806  27.261690  71.927765  17.472292  23.076450
# 2010-01-07  6.321638  48.468555  27.270256  71.678787  17.428860  22.836464
# 2010-01-08  6.363666  48.001011  27.313093  72.398079  17.106276  22.993952

# %%
close.pct_change().dropna()
# Out:
# Ticker          AAPL        BA       DIS       IBM        KO      MSFT
# Date
# 2010-01-05  0.001729  0.032752 -0.002495 -0.012080 -0.012097  0.000323
# 2010-01-06 -0.015906  0.030334 -0.005314 -0.006496 -0.000355 -0.006137
# 2010-01-07 -0.001848  0.040482  0.000314 -0.003461 -0.002486 -0.010400
# 2010-01-08  0.006648 -0.009646  0.001571  0.010035 -0.018509  0.006896
# 2010-01-11 -0.008822 -0.011851 -0.016311 -0.010470  0.020308 -0.012720
# ...              ...       ...       ...       ...       ...       ...
# 2019-01-30  0.068335  0.062509 -0.006943  0.000372  0.009705  0.033417
# 2019-01-31  0.007201 -0.005416  0.012621  0.000297  0.005641 -0.018330
# 2019-02-01  0.000481  0.004694 -0.001973 -0.002380  0.011843 -0.015800
# 2019-02-04  0.028405  0.024701  0.004492  0.008128  0.011294  0.028799
# 2019-02-05  0.017110  0.033199  0.007692  0.002663  0.000203  0.013997
#
# [2287 rows x 6 columns]

# %%
ret = close.pct_change().dropna()

# %%
ret.head()
# Out:
# Ticker          AAPL        BA       DIS       IBM        KO      MSFT
# Date
# 2010-01-05  0.001729  0.032752 -0.002495 -0.012080 -0.012097  0.000323
# 2010-01-06 -0.015906  0.030334 -0.005314 -0.006496 -0.000355 -0.006137
# 2010-01-07 -0.001848  0.040482  0.000314 -0.003461 -0.002486 -0.010400
# 2010-01-08  0.006648 -0.009646  0.001571  0.010035 -0.018509  0.006896
# 2010-01-11 -0.008822 -0.011851 -0.016311 -0.010470  0.020308 -0.012720

# %%
ret.describe().T.loc[:, ["mean", "std"]]
# Out:
#             mean       std
# Ticker
# AAPL    0.000950  0.016383
# BA      0.001085  0.015422
# DIS     0.000691  0.013118
# IBM     0.000195  0.012380
# KO      0.000402  0.009161
# MSFT    0.000748  0.014560

# %%
summary = ret.describe().T.loc[:, ["mean", "std"]]
summary
# Out:
#             mean       std
# Ticker
# AAPL    0.000950  0.016383
# BA      0.001085  0.015422
# DIS     0.000691  0.013118
# IBM     0.000195  0.012380
# KO      0.000402  0.009161
# MSFT    0.000748  0.014560

# %%
summary["mean"] = summary["mean"]*252
summary["std"] = summary["std"] * np.sqrt(252)

# %%
summary
# Out:
#             mean       std
# Ticker
# AAPL    0.239358  0.260066
# BA      0.273457  0.244822
# DIS     0.174102  0.208242
# IBM     0.049193  0.196527
# KO      0.101328  0.145421
# MSFT    0.188401  0.231130

# %%
summary.plot(kind = "scatter", x = "std", y = "mean", figsize = (15,12), s = 50, fontsize = 15)
for i in summary.index:
    plt.annotate(i, xy=(summary.loc[i, "std"]+0.002, summary.loc[i, "mean"]+0.002), size = 15)
plt.xlabel("ann. Risk(std)", fontsize = 15)
plt.ylabel("ann. Return", fontsize = 15)
plt.title("Risk/Return", fontsize = 20)
plt.show()

# %% [markdown]
# ## Financial Time Series - Covariance and Correlation

# %%
ret.head()
# Out:
# Ticker          AAPL        BA       DIS       IBM        KO      MSFT
# Date
# 2010-01-05  0.001729  0.032752 -0.002495 -0.012080 -0.012097  0.000323
# 2010-01-06 -0.015906  0.030334 -0.005314 -0.006496 -0.000355 -0.006137
# 2010-01-07 -0.001848  0.040482  0.000314 -0.003461 -0.002486 -0.010400
# 2010-01-08  0.006648 -0.009646  0.001571  0.010035 -0.018509  0.006896
# 2010-01-11 -0.008822 -0.011851 -0.016311 -0.010470  0.020308 -0.012720

# %%
ret.cov()
# Out:
# Ticker      AAPL        BA       DIS       IBM        KO      MSFT
# Ticker
# AAPL    0.000268  0.000104  0.000080  0.000076  0.000041  0.000107
# BA      0.000104  0.000238  0.000104  0.000087  0.000057  0.000101
# DIS     0.000080  0.000104  0.000172  0.000073  0.000053  0.000086
# IBM     0.000076  0.000087  0.000073  0.000153  0.000047  0.000088
# KO      0.000041  0.000057  0.000053  0.000047  0.000084  0.000051
# MSFT    0.000107  0.000101  0.000086  0.000088  0.000051  0.000212

# %%
ret.corr()
# Out:
# Ticker      AAPL        BA       DIS       IBM        KO      MSFT
# Ticker
# AAPL    1.000000  0.411482  0.374028  0.375721  0.271539  0.450303
# BA      0.411482  1.000000  0.515761  0.456270  0.405449  0.447966
# DIS     0.374028  0.515761  1.000000  0.447932  0.437496  0.451329
# IBM     0.375721  0.456270  0.447932  1.000000  0.410215  0.486612
# KO      0.271539  0.405449  0.437496  0.410215  1.000000  0.382738
# MSFT    0.450303  0.447966  0.451329  0.486612  0.382738  1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(), cmap = "Reds", annot = True, annot_kws={"size":15}, vmax = 0.6)
plt.show()
